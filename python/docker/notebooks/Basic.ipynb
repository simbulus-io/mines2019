# %% [markdown]
# # A simple python snippet to calculate $|\pi-\frac{10}{\pi}|$

# %%
# NOTE: The import of numpy as np and pandas as pd are done globally for notebooks from the 
# python in ..../config/profile_default/startup
print("numpy is already loaded...", np);

abs(np.pi - 10/np.pi)
# Out:
# numpy is already loaded... <module 'numpy' from '/usr/local/lib/python3.7/site-packages/numpy/__init__.py'>
# 0.04150620824811391

# %% [markdown]
# # Plotting with MatPlotLib (and Pandas)
# * Example of using pandas to define a DataFrame
# * Plotting to matplotlib
# * Note the %matplotlib inline directive
# * The None at the end of the code suppresses and Ouput [] block from appearing (try removing "None" and running)
# * Try replacing kind="line" with kind="box" and rerunning

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd

df = pd.DataFrame({
     "2018":[1.3, 1.1, 3.2, 3.7], 
     "2019":[2.1, 3.1, 4.5, 1.2]},
     index=['Jan','Feb','Mar', 'Apr'])

df.plot(kind='line',figsize=(15,10),fontsize=14,grid=False)
plt.ylabel('Rainfall')
None
# Out:
# Text(0, 0.5, 'Rainfall')
